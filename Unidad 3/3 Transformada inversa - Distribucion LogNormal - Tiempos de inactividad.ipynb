# %% [markdown]
# ![](CintillaTecNM-ITD.png)

# %% [markdown]
# # Simulación
#
# ## Unidad 3. Variables Aleatorias
#
# ### Facilitador: José Gabriel Rodríguez Rivas

# %% [markdown]
# <div style="color: blue;">
# <h2> Practica 3: Simular los tiempos de servicio o inactividad en una fábrica de chips.
# </div>
#
# ### Método de la transformada inversa
#
# - El método de la transformada inversa se utiliza para generar variables aleatorias que siguen una distribución específica, **transformando números aleatorios uniformes 𝑈 (0,1) en variables con la distribución deseada.**
#
#
# ### Distribución Lognormal
#
# - La distribución Lognormal es usada principalmente para **modelar tiempos de servicio o inactividad que tienen una asimetría positiva**, es decir, **donde hay más eventos de corta duración, pero algunos pueden ser mucho más largos**.
#
# #### Características:
# - Los valores de la variable son siempre positivos y tienden a distribuirse de manera asimétrica, con una "cola" hacia la derecha.
# - Se usa cuando los tiempos de servicio pueden tener una gran variabilidad y valores extremos.
#
#
# 2. **Función de densidad de probabilidad (PDF)**: La función de densidad de probabilidad de la distribución Lognormal se define como:
#
# ![image-2.png](attachment:image-2.png)
#
#
# #### *μ y σ son los parámetros de la distribución lognormal.*

# %% [markdown]
# ### Ejemplo de Aplicación:
#
# #### Aplicar el método de la transformada inversa para generar variables aleatorias que simulen los  tiempos de servicio o inactividad en una fábrica de chips.
#
# #### Contexto
#
# - En una línea de producción automatizada en la fabricación de chips electrónicos, existen brazos automatizados que se encargan de ensamblar y soldar componentes en las placas de circuitos integrados.
# - En esta parte del proceso de fabricación, es común que los equipos automatizados sufran interrupciones debido a mantenimiento, fallas técnicas menores, o ajustes en los materiales.
# - Estas pausas tienden a seguir una distribución lognormal: muchas son breves, pero ocasionalmente pueden ser más prolongadas debido a problemas más complejos.
# - El uso del método de la transformada inversa permite simular estos tiempos de inactividad, ayudando a evaluar la eficiencia del sistema y a planificar el mantenimiento preventivo para minimizar las interrupciones en la producción de chips.

# %% [markdown]
# ### Pasos para aplicar el método de la transformada inversa con una distribución lognormal:
#
# 1. Modelo de distribución lognormal:
# - Supongamos que los tiempos de inactividad en la fábrica de chips siguen una distribución lognormal. Esto es razonable si los tiempos de inactividad son generalmente cortos, pero ocasionalmente pueden ser mucho más largos, lo que crea una asimetría en los tiempos.
#
# - La distribución lognormal se usa cuando el logaritmo de la variable sigue una distribución normal. Es decir, si 𝑇 es el tiempo de inactividad, entonces ln(𝑇) sigue una distribución normal con media 𝜇 y una desviación estándar 𝜎.
#
# La función de densidad para una variable lognormal es:
#
# ![image.png](attachment:image.png)
#
# 2. Generación de una variable aleatoria lognormal:
# Para generar tiempos de inactividad 𝑇 usando la transformada inversa, necesitamos la función de distribución acumulada (FDA) de la distribución lognormal, denotada como 𝐹𝑇(𝑡), que no tiene una forma cerrada sencilla. Sin embargo, podemos utilizar una aproximación a través del método de transformada inversa basado en la siguiente relación:
#
# - Primero, generamos una variable aleatoria uniforme  **𝑈 ∼𝑈 (0,1).**
# - Luego, aplicamos la inversa de la función de distribución acumulada (FDA) de la **distribución normal sobre ln (𝑇).**
#
#
# #### Proceso paso a paso:
#
# 1-. Generar un número aleatorio  𝑈 ∼𝑈 (0,1): Generamos un número aleatorio 𝑈 utilizando una distribución uniforme entre 0 y 1.
#
# 2-. Aplicar la transformada inversa: Para generar tiempos 𝑇, hacemos lo siguiente:
#
# - Primero, generamos
# ![image-2.png](attachment:image-2.png)
#
# donde:
# ![image-3.png](attachment:image-3.png)
#
# es la inversa de la función de distribución acumulada estándar normal (la función de probabilidad normal inversa).
# - Luego, el tiempo 𝑇 de inactividad (o servicio) se obtiene mediante la transformación:
#
# ![image-4.png](attachment:image-4.png)
#
# 3-. Convertir la variable generada: El valor de 𝑇 ahora es una variable aleatoria lognormal, que representa los tiempos de servicio o inactividad en la fábrica de chips.

# %% [markdown]
# ### Ejemplo aplicado en Python

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parámetros de la distribución lognormal
mu = 1.0   # Media de la variable logarítmica
sigma = 0.5  # Desviación estándar de la variable logarítmica
n = 100  # Número de variables aleatorias a generar

# Generar n números aleatorios U ~ Uniform(0, 1)
U = np.random.uniform(0, 1, n)

# Transformada inversa para generar tiempos de inactividad lognormales
Z = mu + sigma * stats.norm.ppf(U)
T = np.exp(Z)  # Tiempos generados

# Mostrar los resultados
print("Tiempos de inactividad generados:", T)

# Graficar histograma de los tiempos de inactividad generados
plt.hist(T, bins=20, edgecolor='black', density=True)

# Graficar la función teórica de densidad de la distribución lognormal
x = np.linspace(min(T), max(T), 100)
pdf = stats.lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r', label='Distribución lognormal teórica')

plt.title("Histograma de los tiempos de inactividad (Distribución Lognormal)")
plt.xlabel("Tiempo de inactividad")
plt.ylabel("Densidad de probabilidad")
plt.legend()
plt.show()
# Out:
# Tiempos de inactividad generados: [2.01249853 3.87027039 1.49661969 3.23174982 3.7046035  1.79851808
#  6.40236038 3.00830388 4.54211229 3.20467794 2.75986511 1.68593751
#  1.93177638 1.60533248 1.3213275  2.27872909 2.18156694 9.88128883
#  1.74839731 0.71489381 1.97423189 3.71688605 3.75263745 3.84437222
#  1.95423263 3.48248587 1.4955909  2.2469756  2.65925631 2.88239751
#  1.2195073  3.6002197  2.07038697 1.48261935 2.54484689 1.71761628
#  1.40424038 3.83718091 2.78211938 1.76233557 3.65396778 2.09182079
#  1.76650861 3.1908518  1.56734085 4.19366357 1.01661665 2.76260371
#  1.62269769 2.12953836 2.57270681 3.59690182 2.19283201 6.41093028
#  1.56195725 2.74313821 1.76321283 4.12835809 2.67782511 1.87355671
#  2.09422746 3.32832264 3.52381155 1.80602569 2.81241626 0.81304618
#  1.311396   2.87241941 4.0841456  3.21920162 2.89903965 3.22052389
#  3.30117427 4.17817129 2.76223127 2.19782    1.95917006 2.05078036
#  2.97971965 1.40911266 1.76139749 3.09115568 4.49426679 1.97196219
# ...
